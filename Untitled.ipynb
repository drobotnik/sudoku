# %%
from itertools import product, permutations
from copy import copy
from collections import Counter

def pprint(iterable):
    for _ in iterable:
        print(_)

def check(secret, guess):
    # TODO get rid of this turning a copy into a list
    # TODO look at using Counter() to replace this logic
    secret_copy = list(copy(secret))
    zipped_positions = zip(secret, guess)
    black_pegs = 0
    for c, g in zipped_positions:
        if c == g:
            black_pegs += 1
    white_pegs = 0
    for peg in guess:
        if peg in secret_copy:
            white_pegs += 1
            secret_copy.remove(peg)
    return black_pegs, white_pegs - black_pegs


class Mastermind(object):
    def __init__(self, secret, num_colours=6, num_pegs=4, strategy=1, duplicates=True):
        if not duplicates:
            assert num_pegs <= num_colours
        self.strategy = strategy
        self.secret = secret
        self.possible_opts = product(range(num_colours), repeat=num_pegs) if duplicates else permutations(range(num_colours), num_pegs)
        self.num_colours = num_colours
        self.num_pegs = num_pegs
        self.guesses = []
        if strategy == 1:
            self.remaining_opts = list(product(range(num_colours), repeat=num_pegs))
            self.possible_opts = list(product(range(num_colours), repeat=num_pegs))

    def make_guess(self, guess):
        response = self.secret.give_guess_response(guess)
        self.guesses += [(guess, response)]
        # print('Making guess: {}, Response: {}'.format(guess, response))
        return guess, response

    def test_possibility(self, possibility):
        for wrong_guess, wrong_result in self.guesses:
            hypothetical_result = check(possibility, wrong_guess)
            if hypothetical_result != wrong_result:
                return False
        return True

    def knuth_key(self, test_guess):
        """
        Key explanation:
        For your test code
        check that to all the remaining possible secrets
        see how many of the same type of responses you would get for that code against all possible secrets.
        The higher the number, the worse it is as that will be more ambiguous.
        This is because it could be many different secrets which would give you that response from check() given that code.
        Find the highest value from these occurances (worst case).
        That is the score for that code.
        ie. If you got that response, how many different secrets would have given you that code
        """
        test_checker = (check(code, test_guess) for code in self.remaining_opts)  # For each possible code, see what response you would get with the guess you are testing
        group_responses = Counter(test_checker)  # Add up all the different possibilities. eg (0, 2): 50 means-> If you get a response of (0, 2), then it can only be one of 50 possibilites
        wc = group_responses.values()  # We dont care about the different values since we don't know what it will, just how many times each option might appear
        return max(wc)  # We are only interested in the worst case

    def get_next_guess(self):
        if self.strategy == 0:
            next_guess = next(self.possible_opts)
            while not self.test_possibility(next_guess):
                next_guess = next(self.possible_opts)

        elif self.strategy == 1:
            last_guess, last_response = self.guesses[-1]
            filtered_codes = []
            for remaining_opt in self.remaining_opts:  # for each remaining possible code
                if check(remaining_opt, last_guess) == last_response:  # Does that code match what we learnt from the last guess?
                    filtered_codes += [remaining_opt]  # If so, add it to the new list of remaining possible codes
            self.remaining_opts = filtered_codes  # Set codes to only be the remaining possibilities

            if len(self.remaining_opts) == 1:
                next_guess = self.remaining_opts[0]
            else:
                next_guess = min(self.possible_opts, key=self.knuth_key)  # Find the code which would give you the most unambiguous response in the worst case

        else:
            next_guess = next(self.possible_opts)

        return next_guess

    def run(self):
        chosen_guess = [int(x >= self.num_pegs / 2) for x in range(self.num_pegs)]
        option, response = self.make_guess(chosen_guess)
        while True:
            if response == (self.num_pegs, 0):
                return option
            chosen_guess = self.get_next_guess()
            option, response = self.make_guess(chosen_guess)


class Secret(object):
    def __init__(self, secret, num_colours=6, num_pegs=4, duplicates=True):
        assert max(secret) < num_colours, "Peg selected too high"
        assert min(secret) >= 0, "Peg selected below 0"
        assert len(secret) == num_pegs, "Not enough colours picked"
        if not duplicates:
            assert len(secret) == len(set(secret)), "There are duplicated numbers when duplicates are set to false"
        self.secret = secret

    def give_guess_response(self, guess):
        return check(self.secret, guess)


strategies = {
    'naive': 0,
    'knuth': 1,
    'brute_force': 2
}

# %%
def test_all_combinations(colours=6, pegs=4, strategy=0, duplicates=True):
    all_secrets = product(range(colours), repeat=pegs) if duplicates else permutations(range(colours), pegs)
    guess_count = []
    for test_secret in all_secrets:
        s = Secret(test_secret)
        m = Mastermind(s, colours, pegs, strategy, duplicates)
        m.run()
        num_guesses = len(m.guesses)
        guess_count += [num_guesses]
        print("Num guesses: {}, Secret: {}".format(num_guesses, test_secret))

    dist = Counter(guess_count)

    return dist

def single_test(code, num_colours=6, num_pegs=4, strategy=0, duplicates=True):
    s = Secret(code, num_colours=num_colours, num_pegs=num_pegs, duplicates=duplicates)
    m = Mastermind(s, num_colours=num_colours, num_pegs=num_pegs, strategy=strategy, duplicates=duplicates)
    m.run()
    # pprint(m.guesses)
    print("Num Guesses: {}".format(len(m.guesses)))
    return m

# %%
test_all_combinations()
# Out:
# Counter({1: 1, 2: 12, 3: 71, 4: 253, 5: 588, 6: 286, 7: 78, 8: 7})

# %%
test_all_combinations(strategy=1)
# Out:
# Num guesses: 4, Secret: (0, 0, 0, 0)
# Num guesses: 4, Secret: (0, 0, 0, 1)
# Num guesses: 5, Secret: (0, 0, 0, 2)
# Num guesses: 5, Secret: (0, 0, 0, 3)
# Num guesses: 4, Secret: (0, 0, 0, 4)
# Num guesses: 5, Secret: (0, 0, 0, 5)
# Num guesses: 4, Secret: (0, 0, 1, 0)
# Num guesses: 1, Secret: (0, 0, 1, 1)
# Num guesses: 4, Secret: (0, 0, 1, 2)
# Num guesses: 4, Secret: (0, 0, 1, 3)
# Num guesses: 5, Secret: (0, 0, 1, 4)
# Num guesses: 5, Secret: (0, 0, 1, 5)
# Num guesses: 5, Secret: (0, 0, 2, 0)
# Num guesses: 4, Secret: (0, 0, 2, 1)
# Num guesses: 5, Secret: (0, 0, 2, 2)
# Num guesses: 3, Secret: (0, 0, 2, 3)
# Num guesses: 4, Secret: (0, 0, 2, 4)
# Num guesses: 4, Secret: (0, 0, 2, 5)
# Num guesses: 5, Secret: (0, 0, 3, 0)
# Num guesses: 4, Secret: (0, 0, 3, 1)
# Num guesses: 4, Secret: (0, 0, 3, 2)
# Num guesses: 5, Secret: (0, 0, 3, 3)
# Num guesses: 5, Secret: (0, 0, 3, 4)
# Num guesses: 5, Secret: (0, 0, 3, 5)
# Num guesses: 5, Secret: (0, 0, 4, 0)
# Num guesses: 5, Secret: (0, 0, 4, 1)
# Num guesses: 5, Secret: (0, 0, 4, 2)
# Num guesses: 5, Secret: (0, 0, 4, 3)
# Num guesses: 5, Secret: (0, 0, 4, 4)
# Num guesses: 5, Secret: (0, 0, 4, 5)
# Num guesses: 5, Secret: (0, 0, 5, 0)
# Num guesses: 5, Secret: (0, 0, 5, 1)
# Num guesses: 5, Secret: (0, 0, 5, 2)
# Num guesses: 5, Secret: (0, 0, 5, 3)
# Num guesses: 5, Secret: (0, 0, 5, 4)
# Num guesses: 5, Secret: (0, 0, 5, 5)
# Num guesses: 4, Secret: (0, 1, 0, 0)
# Num guesses: 3, Secret: (0, 1, 0, 1)
# Num guesses: 2, Secret: (0, 1, 0, 2)
# Num guesses: 4, Secret: (0, 1, 0, 3)
# Num guesses: 5, Secret: (0, 1, 0, 4)
# Num guesses: 5, Secret: (0, 1, 0, 5)
# Num guesses: 3, Secret: (0, 1, 1, 0)
# Num guesses: 4, Secret: (0, 1, 1, 1)
# Num guesses: 2, Secret: (0, 1, 1, 2)
# Num guesses: 4, Secret: (0, 1, 1, 3)
# Num guesses: 4, Secret: (0, 1, 1, 4)
# Num guesses: 4, Secret: (0, 1, 1, 5)
# Num guesses: 4, Secret: (0, 1, 2, 0)
# Num guesses: 4, Secret: (0, 1, 2, 1)
# Num guesses: 5, Secret: (0, 1, 2, 2)
# Num guesses: 4, Secret: (0, 1, 2, 3)
# Num guesses: 3, Secret: (0, 1, 2, 4)
# Num guesses: 5, Secret: (0, 1, 2, 5)
# Num guesses: 4, Secret: (0, 1, 3, 0)
# Num guesses: 4, Secret: (0, 1, 3, 1)
# Num guesses: 5, Secret: (0, 1, 3, 2)
# Num guesses: 5, Secret: (0, 1, 3, 3)
# Num guesses: 5, Secret: (0, 1, 3, 4)
# Num guesses: 4, Secret: (0, 1, 3, 5)
# Num guesses: 4, Secret: (0, 1, 4, 0)
# Num guesses: 4, Secret: (0, 1, 4, 1)
# Num guesses: 5, Secret: (0, 1, 4, 2)
# Num guesses: 4, Secret: (0, 1, 4, 3)
# Num guesses: 5, Secret: (0, 1, 4, 4)
# Num guesses: 5, Secret: (0, 1, 4, 5)
# Num guesses: 4, Secret: (0, 1, 5, 0)
# Num guesses: 4, Secret: (0, 1, 5, 1)
# Num guesses: 5, Secret: (0, 1, 5, 2)
# Num guesses: 5, Secret: (0, 1, 5, 3)
# Num guesses: 5, Secret: (0, 1, 5, 4)
# Num guesses: 5, Secret: (0, 1, 5, 5)
# Num guesses: 5, Secret: (0, 2, 0, 0)
# Num guesses: 4, Secret: (0, 2, 0, 1)
# Num guesses: 5, Secret: (0, 2, 0, 2)
# Num guesses: 4, Secret: (0, 2, 0, 3)
# Num guesses: 3, Secret: (0, 2, 0, 4)
# Num guesses: 5, Secret: (0, 2, 0, 5)
# Num guesses: 4, Secret: (0, 2, 1, 0)
# Num guesses: 3, Secret: (0, 2, 1, 1)
# Num guesses: 5, Secret: (0, 2, 1, 2)
# Num guesses: 4, Secret: (0, 2, 1, 3)
# Num guesses: 5, Secret: (0, 2, 1, 4)
# Num guesses: 5, Secret: (0, 2, 1, 5)
# Num guesses: 5, Secret: (0, 2, 2, 0)
# Num guesses: 4, Secret: (0, 2, 2, 1)
# Num guesses: 5, Secret: (0, 2, 2, 2)
# Num guesses: 5, Secret: (0, 2, 2, 3)
# Num guesses: 5, Secret: (0, 2, 2, 4)
# Num guesses: 5, Secret: (0, 2, 2, 5)
# Num guesses: 4, Secret: (0, 2, 3, 0)
# Num guesses: 4, Secret: (0, 2, 3, 1)
# Num guesses: 5, Secret: (0, 2, 3, 2)
# Num guesses: 2, Secret: (0, 2, 3, 3)
# Num guesses: 5, Secret: (0, 2, 3, 4)
# Num guesses: 5, Secret: (0, 2, 3, 5)
# Num guesses: 5, Secret: (0, 2, 4, 0)
# Num guesses: 5, Secret: (0, 2, 4, 1)
# Num guesses: 5, Secret: (0, 2, 4, 2)
# Num guesses: 5, Secret: (0, 2, 4, 3)
# Num guesses: 5, Secret: (0, 2, 4, 4)
# Num guesses: 5, Secret: (0, 2, 4, 5)
# Num guesses: 5, Secret: (0, 2, 5, 0)
# Num guesses: 5, Secret: (0, 2, 5, 1)
# Num guesses: 5, Secret: (0, 2, 5, 2)
# Num guesses: 5, Secret: (0, 2, 5, 3)
# Num guesses: 5, Secret: (0, 2, 5, 4)
# Num guesses: 5, Secret: (0, 2, 5, 5)
# Num guesses: 5, Secret: (0, 3, 0, 0)
# Num guesses: 4, Secret: (0, 3, 0, 1)
# Num guesses: 4, Secret: (0, 3, 0, 2)
# Num guesses: 5, Secret: (0, 3, 0, 3)
# Num guesses: 5, Secret: (0, 3, 0, 4)
# Num guesses: 5, Secret: (0, 3, 0, 5)
# Num guesses: 4, Secret: (0, 3, 1, 0)
# Num guesses: 4, Secret: (0, 3, 1, 1)
# Num guesses: 4, Secret: (0, 3, 1, 2)
# Num guesses: 4, Secret: (0, 3, 1, 3)
# Num guesses: 5, Secret: (0, 3, 1, 4)
# Num guesses: 5, Secret: (0, 3, 1, 5)
# Num guesses: 4, Secret: (0, 3, 2, 0)
# Num guesses: 4, Secret: (0, 3, 2, 1)
# Num guesses: 5, Secret: (0, 3, 2, 2)
# Num guesses: 4, Secret: (0, 3, 2, 3)
# Num guesses: 5, Secret: (0, 3, 2, 4)
# Num guesses: 5, Secret: (0, 3, 2, 5)
# Num guesses: 5, Secret: (0, 3, 3, 0)
# Num guesses: 5, Secret: (0, 3, 3, 1)
# Num guesses: 4, Secret: (0, 3, 3, 2)
# Num guesses: 5, Secret: (0, 3, 3, 3)
# Num guesses: 4, Secret: (0, 3, 3, 4)
# Num guesses: 5, Secret: (0, 3, 3, 5)
# Num guesses: 5, Secret: (0, 3, 4, 0)
# Num guesses: 4, Secret: (0, 3, 4, 1)
# Num guesses: 4, Secret: (0, 3, 4, 2)
# Num guesses: 4, Secret: (0, 3, 4, 3)
# Num guesses: 5, Secret: (0, 3, 4, 4)
# Num guesses: 5, Secret: (0, 3, 4, 5)
# Num guesses: 5, Secret: (0, 3, 5, 0)
# Num guesses: 5, Secret: (0, 3, 5, 1)
# Num guesses: 5, Secret: (0, 3, 5, 2)
# Num guesses: 5, Secret: (0, 3, 5, 3)
# Num guesses: 5, Secret: (0, 3, 5, 4)
# Num guesses: 5, Secret: (0, 3, 5, 5)
# Num guesses: 5, Secret: (0, 4, 0, 0)
# Num guesses: 4, Secret: (0, 4, 0, 1)
# Num guesses: 5, Secret: (0, 4, 0, 2)
# Num guesses: 5, Secret: (0, 4, 0, 3)
# Num guesses: 5, Secret: (0, 4, 0, 4)
# Num guesses: 3, Secret: (0, 4, 0, 5)
# Num guesses: 4, Secret: (0, 4, 1, 0)
# Num guesses: 4, Secret: (0, 4, 1, 1)
# Num guesses: 5, Secret: (0, 4, 1, 2)
# Num guesses: 4, Secret: (0, 4, 1, 3)
# Num guesses: 5, Secret: (0, 4, 1, 4)
# Num guesses: 5, Secret: (0, 4, 1, 5)
# Num guesses: 4, Secret: (0, 4, 2, 0)
# Num guesses: 4, Secret: (0, 4, 2, 1)
# Num guesses: 5, Secret: (0, 4, 2, 2)
# Num guesses: 5, Secret: (0, 4, 2, 3)
# Num guesses: 5, Secret: (0, 4, 2, 4)
# Num guesses: 4, Secret: (0, 4, 2, 5)
# Num guesses: 5, Secret: (0, 4, 3, 0)
# Num guesses: 5, Secret: (0, 4, 3, 1)
# Num guesses: 5, Secret: (0, 4, 3, 2)
# Num guesses: 4, Secret: (0, 4, 3, 3)
# Num guesses: 5, Secret: (0, 4, 3, 4)
# Num guesses: 5, Secret: (0, 4, 3, 5)
# Num guesses: 5, Secret: (0, 4, 4, 0)
# Num guesses: 5, Secret: (0, 4, 4, 1)
# Num guesses: 5, Secret: (0, 4, 4, 2)
# Num guesses: 5, Secret: (0, 4, 4, 3)
# Num guesses: 5, Secret: (0, 4, 4, 4)
# Num guesses: 5, Secret: (0, 4, 4, 5)
# Num guesses: 5, Secret: (0, 4, 5, 0)
# Num guesses: 5, Secret: (0, 4, 5, 1)
# Num guesses: 5, Secret: (0, 4, 5, 2)
# Num guesses: 5, Secret: (0, 4, 5, 3)
# Num guesses: 5, Secret: (0, 4, 5, 4)
# Num guesses: 5, Secret: (0, 4, 5, 5)
# Num guesses: 5, Secret: (0, 5, 0, 0)
# Num guesses: 4, Secret: (0, 5, 0, 1)
# Num guesses: 5, Secret: (0, 5, 0, 2)
# Num guesses: 5, Secret: (0, 5, 0, 3)
# Num guesses: 5, Secret: (0, 5, 0, 4)
# Num guesses: 5, Secret: (0, 5, 0, 5)
# Num guesses: 4, Secret: (0, 5, 1, 0)
# Num guesses: 4, Secret: (0, 5, 1, 1)
# Num guesses: 5, Secret: (0, 5, 1, 2)
# Num guesses: 4, Secret: (0, 5, 1, 3)
# Num guesses: 5, Secret: (0, 5, 1, 4)
# Num guesses: 5, Secret: (0, 5, 1, 5)
# Num guesses: 5, Secret: (0, 5, 2, 0)
# Num guesses: 4, Secret: (0, 5, 2, 1)
# Num guesses: 5, Secret: (0, 5, 2, 2)
# Num guesses: 5, Secret: (0, 5, 2, 3)
# Num guesses: 5, Secret: (0, 5, 2, 4)
# Num guesses: 5, Secret: (0, 5, 2, 5)
# Num guesses: 5, Secret: (0, 5, 3, 0)
# Num guesses: 5, Secret: (0, 5, 3, 1)
# Num guesses: 5, Secret: (0, 5, 3, 2)
# Num guesses: 5, Secret: (0, 5, 3, 3)
# Num guesses: 5, Secret: (0, 5, 3, 4)
# Num guesses: 5, Secret: (0, 5, 3, 5)
# Num guesses: 5, Secret: (0, 5, 4, 0)
# Num guesses: 5, Secret: (0, 5, 4, 1)
# Num guesses: 5, Secret: (0, 5, 4, 2)
# Num guesses: 5, Secret: (0, 5, 4, 3)
# Num guesses: 5, Secret: (0, 5, 4, 4)
# Num guesses: 5, Secret: (0, 5, 4, 5)
# Num guesses: 5, Secret: (0, 5, 5, 0)
# Num guesses: 5, Secret: (0, 5, 5, 1)
# Num guesses: 5, Secret: (0, 5, 5, 2)
# Num guesses: 5, Secret: (0, 5, 5, 3)
# Num guesses: 5, Secret: (0, 5, 5, 4)
# Num guesses: 4, Secret: (0, 5, 5, 5)
# Num guesses: 4, Secret: (1, 0, 0, 0)
# Num guesses: 3, Secret: (1, 0, 0, 1)
# Num guesses: 4, Secret: (1, 0, 0, 2)
# Num guesses: 4, Secret: (1, 0, 0, 3)
# Num guesses: 5, Secret: (1, 0, 0, 4)
# Num guesses: 5, Secret: (1, 0, 0, 5)
# Num guesses: 3, Secret: (1, 0, 1, 0)
# Num guesses: 5, Secret: (1, 0, 1, 1)
# Num guesses: 4, Secret: (1, 0, 1, 2)
# Num guesses: 4, Secret: (1, 0, 1, 3)
# Num guesses: 4, Secret: (1, 0, 1, 4)
# Num guesses: 4, Secret: (1, 0, 1, 5)
# Num guesses: 3, Secret: (1, 0, 2, 0)
# Num guesses: 3, Secret: (1, 0, 2, 1)
# Num guesses: 5, Secret: (1, 0, 2, 2)
# Num guesses: 4, Secret: (1, 0, 2, 3)
# Num guesses: 4, Secret: (1, 0, 2, 4)
# Num guesses: 5, Secret: (1, 0, 2, 5)
# Num guesses: 4, Secret: (1, 0, 3, 0)
# Num guesses: 4, Secret: (1, 0, 3, 1)
# Num guesses: 5, Secret: (1, 0, 3, 2)
# Num guesses: 5, Secret: (1, 0, 3, 3)
# Num guesses: 5, Secret: (1, 0, 3, 4)
# Num guesses: 5, Secret: (1, 0, 3, 5)
# Num guesses: 4, Secret: (1, 0, 4, 0)
# Num guesses: 4, Secret: (1, 0, 4, 1)
# Num guesses: 5, Secret: (1, 0, 4, 2)
# Num guesses: 4, Secret: (1, 0, 4, 3)
# Num guesses: 5, Secret: (1, 0, 4, 4)
# Num guesses: 4, Secret: (1, 0, 4, 5)
# Num guesses: 4, Secret: (1, 0, 5, 0)
# Num guesses: 4, Secret: (1, 0, 5, 1)
# Num guesses: 5, Secret: (1, 0, 5, 2)
# Num guesses: 5, Secret: (1, 0, 5, 3)
# Num guesses: 5, Secret: (1, 0, 5, 4)
# Num guesses: 5, Secret: (1, 0, 5, 5)
# Num guesses: 2, Secret: (1, 1, 0, 0)
# Num guesses: 5, Secret: (1, 1, 0, 1)
# Num guesses: 3, Secret: (1, 1, 0, 2)
# Num guesses: 4, Secret: (1, 1, 0, 3)
# Num guesses: 4, Secret: (1, 1, 0, 4)
# Num guesses: 4, Secret: (1, 1, 0, 5)
# Num guesses: 5, Secret: (1, 1, 1, 0)
# Num guesses: 5, Secret: (1, 1, 1, 1)
# Num guesses: 5, Secret: (1, 1, 1, 2)
# Num guesses: 5, Secret: (1, 1, 1, 3)
# Num guesses: 5, Secret: (1, 1, 1, 4)
# Num guesses: 5, Secret: (1, 1, 1, 5)
# Num guesses: 4, Secret: (1, 1, 2, 0)
# Num guesses: 5, Secret: (1, 1, 2, 1)
# Num guesses: 5, Secret: (1, 1, 2, 2)
# Num guesses: 4, Secret: (1, 1, 2, 3)
# Num guesses: 5, Secret: (1, 1, 2, 4)
# Num guesses: 5, Secret: (1, 1, 2, 5)
# Num guesses: 4, Secret: (1, 1, 3, 0)
# Num guesses: 5, Secret: (1, 1, 3, 1)
# Num guesses: 4, Secret: (1, 1, 3, 2)
# Num guesses: 4, Secret: (1, 1, 3, 3)
# Num guesses: 5, Secret: (1, 1, 3, 4)
# Num guesses: 5, Secret: (1, 1, 3, 5)
# Num guesses: 4, Secret: (1, 1, 4, 0)
# Num guesses: 5, Secret: (1, 1, 4, 1)
# Num guesses: 5, Secret: (1, 1, 4, 2)
# Num guesses: 5, Secret: (1, 1, 4, 3)
# Num guesses: 4, Secret: (1, 1, 4, 4)
# Num guesses: 5, Secret: (1, 1, 4, 5)
# Num guesses: 4, Secret: (1, 1, 5, 0)
# Num guesses: 5, Secret: (1, 1, 5, 1)
# Num guesses: 5, Secret: (1, 1, 5, 2)
# Num guesses: 5, Secret: (1, 1, 5, 3)
# Num guesses: 5, Secret: (1, 1, 5, 4)
# Num guesses: 4, Secret: (1, 1, 5, 5)
# Num guesses: 3, Secret: (1, 2, 0, 0)
# Num guesses: 4, Secret: (1, 2, 0, 1)
# Num guesses: 4, Secret: (1, 2, 0, 2)
# Num guesses: 4, Secret: (1, 2, 0, 3)
# Num guesses: 4, Secret: (1, 2, 0, 4)
# Num guesses: 4, Secret: (1, 2, 0, 5)
# Num guesses: 4, Secret: (1, 2, 1, 0)
# Num guesses: 5, Secret: (1, 2, 1, 1)
# Num guesses: 5, Secret: (1, 2, 1, 2)
# Num guesses: 5, Secret: (1, 2, 1, 3)
# Num guesses: 5, Secret: (1, 2, 1, 4)
# Num guesses: 5, Secret: (1, 2, 1, 5)
# Num guesses: 5, Secret: (1, 2, 2, 0)
# Num guesses: 5, Secret: (1, 2, 2, 1)
# Num guesses: 5, Secret: (1, 2, 2, 2)
# Num guesses: 5, Secret: (1, 2, 2, 3)
# Num guesses: 5, Secret: (1, 2, 2, 4)
# Num guesses: 5, Secret: (1, 2, 2, 5)
# Num guesses: 4, Secret: (1, 2, 3, 0)
# Num guesses: 5, Secret: (1, 2, 3, 1)
# Num guesses: 5, Secret: (1, 2, 3, 2)
# Num guesses: 2, Secret: (1, 2, 3, 3)
# Num guesses: 5, Secret: (1, 2, 3, 4)
# Num guesses: 5, Secret: (1, 2, 3, 5)
# Num guesses: 5, Secret: (1, 2, 4, 0)
# Num guesses: 5, Secret: (1, 2, 4, 1)
# Num guesses: 5, Secret: (1, 2, 4, 2)
# Num guesses: 5, Secret: (1, 2, 4, 3)
# Num guesses: 5, Secret: (1, 2, 4, 4)
# Num guesses: 5, Secret: (1, 2, 4, 5)
# Num guesses: 5, Secret: (1, 2, 5, 0)
# Num guesses: 5, Secret: (1, 2, 5, 1)
# Num guesses: 5, Secret: (1, 2, 5, 2)
# Num guesses: 5, Secret: (1, 2, 5, 3)
# Num guesses: 5, Secret: (1, 2, 5, 4)
# Num guesses: 5, Secret: (1, 2, 5, 5)
# Num guesses: 4, Secret: (1, 3, 0, 0)
# Num guesses: 5, Secret: (1, 3, 0, 1)
# Num guesses: 3, Secret: (1, 3, 0, 2)
# Num guesses: 4, Secret: (1, 3, 0, 3)
# Num guesses: 4, Secret: (1, 3, 0, 4)
# Num guesses: 4, Secret: (1, 3, 0, 5)
# Num guesses: 4, Secret: (1, 3, 1, 0)
# Num guesses: 5, Secret: (1, 3, 1, 1)
# Num guesses: 5, Secret: (1, 3, 1, 2)
# Num guesses: 5, Secret: (1, 3, 1, 3)
# Num guesses: 5, Secret: (1, 3, 1, 4)
# Num guesses: 5, Secret: (1, 3, 1, 5)
# Num guesses: 4, Secret: (1, 3, 2, 0)
# Num guesses: 5, Secret: (1, 3, 2, 1)
# Num guesses: 5, Secret: (1, 3, 2, 2)
# Num guesses: 4, Secret: (1, 3, 2, 3)
# Num guesses: 5, Secret: (1, 3, 2, 4)
# Num guesses: 5, Secret: (1, 3, 2, 5)
# Num guesses: 4, Secret: (1, 3, 3, 0)
# Num guesses: 5, Secret: (1, 3, 3, 1)
# Num guesses: 4, Secret: (1, 3, 3, 2)
# Num guesses: 5, Secret: (1, 3, 3, 3)
# Num guesses: 4, Secret: (1, 3, 3, 4)
# Num guesses: 5, Secret: (1, 3, 3, 5)
# Num guesses: 5, Secret: (1, 3, 4, 0)
# Num guesses: 5, Secret: (1, 3, 4, 1)
# Num guesses: 4, Secret: (1, 3, 4, 2)
# Num guesses: 4, Secret: (1, 3, 4, 3)
# Num guesses: 5, Secret: (1, 3, 4, 4)
# Num guesses: 5, Secret: (1, 3, 4, 5)
# Num guesses: 5, Secret: (1, 3, 5, 0)
# Num guesses: 5, Secret: (1, 3, 5, 1)
# Num guesses: 5, Secret: (1, 3, 5, 2)
# Num guesses: 5, Secret: (1, 3, 5, 3)
# Num guesses: 5, Secret: (1, 3, 5, 4)
# Num guesses: 5, Secret: (1, 3, 5, 5)
# Num guesses: 4, Secret: (1, 4, 0, 0)
# Num guesses: 5, Secret: (1, 4, 0, 1)
# Num guesses: 5, Secret: (1, 4, 0, 2)
# Num guesses: 5, Secret: (1, 4, 0, 3)
# Num guesses: 5, Secret: (1, 4, 0, 4)
# Num guesses: 5, Secret: (1, 4, 0, 5)
# Num guesses: 4, Secret: (1, 4, 1, 0)
# Num guesses: 4, Secret: (1, 4, 1, 1)
# Num guesses: 5, Secret: (1, 4, 1, 2)
# Num guesses: 5, Secret: (1, 4, 1, 3)
# Num guesses: 3, Secret: (1, 4, 1, 4)
# Num guesses: 5, Secret: (1, 4, 1, 5)
# Num guesses: 5, Secret: (1, 4, 2, 0)
# Num guesses: 5, Secret: (1, 4, 2, 1)
# Num guesses: 5, Secret: (1, 4, 2, 2)
# Num guesses: 5, Secret: (1, 4, 2, 3)
# Num guesses: 5, Secret: (1, 4, 2, 4)
# Num guesses: 5, Secret: (1, 4, 2, 5)
# Num guesses: 4, Secret: (1, 4, 3, 0)
# Num guesses: 5, Secret: (1, 4, 3, 1)
# Num guesses: 5, Secret: (1, 4, 3, 2)
# Num guesses: 4, Secret: (1, 4, 3, 3)
# Num guesses: 4, Secret: (1, 4, 3, 4)
# Num guesses: 5, Secret: (1, 4, 3, 5)
# Num guesses: 5, Secret: (1, 4, 4, 0)
# Num guesses: 5, Secret: (1, 4, 4, 1)
# Num guesses: 5, Secret: (1, 4, 4, 2)
# Num guesses: 5, Secret: (1, 4, 4, 3)
# Num guesses: 5, Secret: (1, 4, 4, 4)
# Num guesses: 5, Secret: (1, 4, 4, 5)
# Num guesses: 5, Secret: (1, 4, 5, 0)
# Num guesses: 5, Secret: (1, 4, 5, 1)
# Num guesses: 5, Secret: (1, 4, 5, 2)
# Num guesses: 5, Secret: (1, 4, 5, 3)
# Num guesses: 5, Secret: (1, 4, 5, 4)
# Num guesses: 5, Secret: (1, 4, 5, 5)
# Num guesses: 4, Secret: (1, 5, 0, 0)
# Num guesses: 4, Secret: (1, 5, 0, 1)
# Num guesses: 5, Secret: (1, 5, 0, 2)
# Num guesses: 5, Secret: (1, 5, 0, 3)
# Num guesses: 5, Secret: (1, 5, 0, 4)
# Num guesses: 5, Secret: (1, 5, 0, 5)
# Num guesses: 4, Secret: (1, 5, 1, 0)
# Num guesses: 4, Secret: (1, 5, 1, 1)
# Num guesses: 5, Secret: (1, 5, 1, 2)
# Num guesses: 5, Secret: (1, 5, 1, 3)
# Num guesses: 5, Secret: (1, 5, 1, 4)
# Num guesses: 5, Secret: (1, 5, 1, 5)
# Num guesses: 5, Secret: (1, 5, 2, 0)
# Num guesses: 5, Secret: (1, 5, 2, 1)
# Num guesses: 5, Secret: (1, 5, 2, 2)
# Num guesses: 5, Secret: (1, 5, 2, 3)
# Num guesses: 5, Secret: (1, 5, 2, 4)
# Num guesses: 5, Secret: (1, 5, 2, 5)
# Num guesses: 5, Secret: (1, 5, 3, 0)
# Num guesses: 5, Secret: (1, 5, 3, 1)
# Num guesses: 5, Secret: (1, 5, 3, 2)
# Num guesses: 5, Secret: (1, 5, 3, 3)
# Num guesses: 5, Secret: (1, 5, 3, 4)
# Num guesses: 5, Secret: (1, 5, 3, 5)
# Num guesses: 5, Secret: (1, 5, 4, 0)
# Num guesses: 5, Secret: (1, 5, 4, 1)
# Num guesses: 5, Secret: (1, 5, 4, 2)
# Num guesses: 5, Secret: (1, 5, 4, 3)
# Num guesses: 5, Secret: (1, 5, 4, 4)
# Num guesses: 5, Secret: (1, 5, 4, 5)
# Num guesses: 5, Secret: (1, 5, 5, 0)
# Num guesses: 5, Secret: (1, 5, 5, 1)
# Num guesses: 5, Secret: (1, 5, 5, 2)
# Num guesses: 5, Secret: (1, 5, 5, 3)
# Num guesses: 5, Secret: (1, 5, 5, 4)
# Num guesses: 4, Secret: (1, 5, 5, 5)
# Num guesses: 5, Secret: (2, 0, 0, 0)
# Num guesses: 4, Secret: (2, 0, 0, 1)
# Num guesses: 5, Secret: (2, 0, 0, 2)
# Num guesses: 4, Secret: (2, 0, 0, 3)
# Num guesses: 5, Secret: (2, 0, 0, 4)
# Num guesses: 5, Secret: (2, 0, 0, 5)
# Num guesses: 4, Secret: (2, 0, 1, 0)
# Num guesses: 3, Secret: (2, 0, 1, 1)
# Num guesses: 5, Secret: (2, 0, 1, 2)
# Num guesses: 4, Secret: (2, 0, 1, 3)
# Num guesses: 4, Secret: (2, 0, 1, 4)
# Num guesses: 5, Secret: (2, 0, 1, 5)
# Num guesses: 5, Secret: (2, 0, 2, 0)
# Num guesses: 5, Secret: (2, 0, 2, 1)
# Num guesses: 5, Secret: (2, 0, 2, 2)
# Num guesses: 5, Secret: (2, 0, 2, 3)
# Num guesses: 3, Secret: (2, 0, 2, 4)
# Num guesses: 5, Secret: (2, 0, 2, 5)
# Num guesses: 4, Secret: (2, 0, 3, 0)
# Num guesses: 4, Secret: (2, 0, 3, 1)
# Num guesses: 5, Secret: (2, 0, 3, 2)
# Num guesses: 4, Secret: (2, 0, 3, 3)
# Num guesses: 3, Secret: (2, 0, 3, 4)
# Num guesses: 5, Secret: (2, 0, 3, 5)
# Num guesses: 4, Secret: (2, 0, 4, 0)
# Num guesses: 4, Secret: (2, 0, 4, 1)
# Num guesses: 5, Secret: (2, 0, 4, 2)
# Num guesses: 5, Secret: (2, 0, 4, 3)
# Num guesses: 5, Secret: (2, 0, 4, 4)
# Num guesses: 5, Secret: (2, 0, 4, 5)
# Num guesses: 5, Secret: (2, 0, 5, 0)
# Num guesses: 5, Secret: (2, 0, 5, 1)
# Num guesses: 5, Secret: (2, 0, 5, 2)
# Num guesses: 5, Secret: (2, 0, 5, 3)
# Num guesses: 5, Secret: (2, 0, 5, 4)
# Num guesses: 5, Secret: (2, 0, 5, 5)
# Num guesses: 3, Secret: (2, 1, 0, 0)
# Num guesses: 4, Secret: (2, 1, 0, 1)
# Num guesses: 5, Secret: (2, 1, 0, 2)
# Num guesses: 4, Secret: (2, 1, 0, 3)
# Num guesses: 4, Secret: (2, 1, 0, 4)
# Num guesses: 5, Secret: (2, 1, 0, 5)
# Num guesses: 4, Secret: (2, 1, 1, 0)
# Num guesses: 5, Secret: (2, 1, 1, 1)
# Num guesses: 5, Secret: (2, 1, 1, 2)
# Num guesses: 5, Secret: (2, 1, 1, 3)
# Num guesses: 5, Secret: (2, 1, 1, 4)
# Num guesses: 5, Secret: (2, 1, 1, 5)
# Num guesses: 5, Secret: (2, 1, 2, 0)
# Num guesses: 5, Secret: (2, 1, 2, 1)
# Num guesses: 5, Secret: (2, 1, 2, 2)
# Num guesses: 5, Secret: (2, 1, 2, 3)
# Num guesses: 3, Secret: (2, 1, 2, 4)
# Num guesses: 5, Secret: (2, 1, 2, 5)
# Num guesses: 4, Secret: (2, 1, 3, 0)
# Num guesses: 5, Secret: (2, 1, 3, 1)
# Num guesses: 5, Secret: (2, 1, 3, 2)
# Num guesses: 4, Secret: (2, 1, 3, 3)
# Num guesses: 3, Secret: (2, 1, 3, 4)
# Num guesses: 5, Secret: (2, 1, 3, 5)
# Num guesses: 5, Secret: (2, 1, 4, 0)
# Num guesses: 5, Secret: (2, 1, 4, 1)
# Num guesses: 5, Secret: (2, 1, 4, 2)
# Num guesses: 5, Secret: (2, 1, 4, 3)
# Num guesses: 5, Secret: (2, 1, 4, 4)
# Num guesses: 5, Secret: (2, 1, 4, 5)
# Num guesses: 5, Secret: (2, 1, 5, 0)
# Num guesses: 5, Secret: (2, 1, 5, 1)
# Num guesses: 5, Secret: (2, 1, 5, 2)
# Num guesses: 5, Secret: (2, 1, 5, 3)
# Num guesses: 5, Secret: (2, 1, 5, 4)
# Num guesses: 5, Secret: (2, 1, 5, 5)
# Num guesses: 5, Secret: (2, 2, 0, 0)
# Num guesses: 4, Secret: (2, 2, 0, 1)
# Num guesses: 5, Secret: (2, 2, 0, 2)
# Num guesses: 5, Secret: (2, 2, 0, 3)
# Num guesses: 5, Secret: (2, 2, 0, 4)
# Num guesses: 5, Secret: (2, 2, 0, 5)
# Num guesses: 5, Secret: (2, 2, 1, 0)
# Num guesses: 5, Secret: (2, 2, 1, 1)
# Num guesses: 5, Secret: (2, 2, 1, 2)
# Num guesses: 5, Secret: (2, 2, 1, 3)
# Num guesses: 5, Secret: (2, 2, 1, 4)
# Num guesses: 5, Secret: (2, 2, 1, 5)
# Num guesses: 5, Secret: (2, 2, 2, 0)
# Num guesses: 5, Secret: (2, 2, 2, 1)
# Num guesses: 5, Secret: (2, 2, 2, 2)
# Num guesses: 5, Secret: (2, 2, 2, 3)
# Num guesses: 5, Secret: (2, 2, 2, 4)
# Num guesses: 5, Secret: (2, 2, 2, 5)
# Num guesses: 5, Secret: (2, 2, 3, 0)
# Num guesses: 5, Secret: (2, 2, 3, 1)
# Num guesses: 5, Secret: (2, 2, 3, 2)
# Num guesses: 5, Secret: (2, 2, 3, 3)
# Num guesses: 2, Secret: (2, 2, 3, 4)
# Num guesses: 5, Secret: (2, 2, 3, 5)
# Num guesses: 5, Secret: (2, 2, 4, 0)
# Num guesses: 5, Secret: (2, 2, 4, 1)
# Num guesses: 5, Secret: (2, 2, 4, 2)
# Num guesses: 4, Secret: (2, 2, 4, 3)
# Num guesses: 5, Secret: (2, 2, 4, 4)
# Num guesses: 5, Secret: (2, 2, 4, 5)
# Num guesses: 5, Secret: (2, 2, 5, 0)
# Num guesses: 5, Secret: (2, 2, 5, 1)
# Num guesses: 5, Secret: (2, 2, 5, 2)
# Num guesses: 5, Secret: (2, 2, 5, 3)
# Num guesses: 5, Secret: (2, 2, 5, 4)
# Num guesses: 4, Secret: (2, 2, 5, 5)
# Num guesses: 5, Secret: (2, 3, 0, 0)
# Num guesses: 4, Secret: (2, 3, 0, 1)
# Num guesses: 5, Secret: (2, 3, 0, 2)
# Num guesses: 5, Secret: (2, 3, 0, 3)
# Num guesses: 5, Secret: (2, 3, 0, 4)
# Num guesses: 5, Secret: (2, 3, 0, 5)
# Num guesses: 4, Secret: (2, 3, 1, 0)
# Num guesses: 5, Secret: (2, 3, 1, 1)
# Num guesses: 5, Secret: (2, 3, 1, 2)
# Num guesses: 5, Secret: (2, 3, 1, 3)
# Num guesses: 5, Secret: (2, 3, 1, 4)
# Num guesses: 5, Secret: (2, 3, 1, 5)
# Num guesses: 5, Secret: (2, 3, 2, 0)
# Num guesses: 5, Secret: (2, 3, 2, 1)
# Num guesses: 5, Secret: (2, 3, 2, 2)
# Num guesses: 5, Secret: (2, 3, 2, 3)
# Num guesses: 5, Secret: (2, 3, 2, 4)
# Num guesses: 5, Secret: (2, 3, 2, 5)
# Num guesses: 5, Secret: (2, 3, 3, 0)
# Num guesses: 5, Secret: (2, 3, 3, 1)
# Num guesses: 4, Secret: (2, 3, 3, 2)
# Num guesses: 5, Secret: (2, 3, 3, 3)
# Num guesses: 5, Secret: (2, 3, 3, 4)
# Num guesses: 5, Secret: (2, 3, 3, 5)
# Num guesses: 5, Secret: (2, 3, 4, 0)
# Num guesses: 5, Secret: (2, 3, 4, 1)
# Num guesses: 4, Secret: (2, 3, 4, 2)
# Num guesses: 3, Secret: (2, 3, 4, 3)
# Num guesses: 5, Secret: (2, 3, 4, 4)
# Num guesses: 5, Secret: (2, 3, 4, 5)
# Num guesses: 5, Secret: (2, 3, 5, 0)
# Num guesses: 5, Secret: (2, 3, 5, 1)
# Num guesses: 5, Secret: (2, 3, 5, 2)
# Num guesses: 5, Secret: (2, 3, 5, 3)
# Num guesses: 5, Secret: (2, 3, 5, 4)
# Num guesses: 5, Secret: (2, 3, 5, 5)
# Num guesses: 5, Secret: (2, 4, 0, 0)
# Num guesses: 5, Secret: (2, 4, 0, 1)
# Num guesses: 5, Secret: (2, 4, 0, 2)
# Num guesses: 5, Secret: (2, 4, 0, 3)
# Num guesses: 5, Secret: (2, 4, 0, 4)
# Num guesses: 5, Secret: (2, 4, 0, 5)
# Num guesses: 5, Secret: (2, 4, 1, 0)
# Num guesses: 5, Secret: (2, 4, 1, 1)
# Num guesses: 5, Secret: (2, 4, 1, 2)
# Num guesses: 5, Secret: (2, 4, 1, 3)
# Num guesses: 5, Secret: (2, 4, 1, 4)
# Num guesses: 5, Secret: (2, 4, 1, 5)
# Num guesses: 5, Secret: (2, 4, 2, 0)
# Num guesses: 5, Secret: (2, 4, 2, 1)
# Num guesses: 5, Secret: (2, 4, 2, 2)
# Num guesses: 4, Secret: (2, 4, 2, 3)
# Num guesses: 5, Secret: (2, 4, 2, 4)
# Num guesses: 5, Secret: (2, 4, 2, 5)
# Num guesses: 4, Secret: (2, 4, 3, 0)
# Num guesses: 4, Secret: (2, 4, 3, 1)
# Num guesses: 5, Secret: (2, 4, 3, 2)
# Num guesses: 5, Secret: (2, 4, 3, 3)
# Num guesses: 5, Secret: (2, 4, 3, 4)
# Num guesses: 5, Secret: (2, 4, 3, 5)
# Num guesses: 5, Secret: (2, 4, 4, 0)
# Num guesses: 5, Secret: (2, 4, 4, 1)
# Num guesses: 5, Secret: (2, 4, 4, 2)
# Num guesses: 5, Secret: (2, 4, 4, 3)
# Num guesses: 5, Secret: (2, 4, 4, 4)
# Num guesses: 5, Secret: (2, 4, 4, 5)
# Num guesses: 5, Secret: (2, 4, 5, 0)
# Num guesses: 5, Secret: (2, 4, 5, 1)
# Num guesses: 5, Secret: (2, 4, 5, 2)
# Num guesses: 5, Secret: (2, 4, 5, 3)
# Num guesses: 5, Secret: (2, 4, 5, 4)
# Num guesses: 5, Secret: (2, 4, 5, 5)
# Num guesses: 5, Secret: (2, 5, 0, 0)
# Num guesses: 5, Secret: (2, 5, 0, 1)
# Num guesses: 5, Secret: (2, 5, 0, 2)
# Num guesses: 5, Secret: (2, 5, 0, 3)
# Num guesses: 5, Secret: (2, 5, 0, 4)
# Num guesses: 5, Secret: (2, 5, 0, 5)
# Num guesses: 5, Secret: (2, 5, 1, 0)
# Num guesses: 5, Secret: (2, 5, 1, 1)
# Num guesses: 5, Secret: (2, 5, 1, 2)
# Num guesses: 5, Secret: (2, 5, 1, 3)
# Num guesses: 5, Secret: (2, 5, 1, 4)
# Num guesses: 5, Secret: (2, 5, 1, 5)
# Num guesses: 5, Secret: (2, 5, 2, 0)
# Num guesses: 5, Secret: (2, 5, 2, 1)
# Num guesses: 5, Secret: (2, 5, 2, 2)
# Num guesses: 5, Secret: (2, 5, 2, 3)
# Num guesses: 5, Secret: (2, 5, 2, 4)
# Num guesses: 5, Secret: (2, 5, 2, 5)
# Num guesses: 5, Secret: (2, 5, 3, 0)
# Num guesses: 5, Secret: (2, 5, 3, 1)
# Num guesses: 5, Secret: (2, 5, 3, 2)
# Num guesses: 5, Secret: (2, 5, 3, 3)
# Num guesses: 5, Secret: (2, 5, 3, 4)
# Num guesses: 5, Secret: (2, 5, 3, 5)
# Num guesses: 5, Secret: (2, 5, 4, 0)
# Num guesses: 5, Secret: (2, 5, 4, 1)
# Num guesses: 5, Secret: (2, 5, 4, 2)
# Num guesses: 5, Secret: (2, 5, 4, 3)
# Num guesses: 5, Secret: (2, 5, 4, 4)
# Num guesses: 5, Secret: (2, 5, 4, 5)
# Num guesses: 5, Secret: (2, 5, 5, 0)
# Num guesses: 5, Secret: (2, 5, 5, 1)
# Num guesses: 5, Secret: (2, 5, 5, 2)
# Num guesses: 5, Secret: (2, 5, 5, 3)
# Num guesses: 4, Secret: (2, 5, 5, 4)
# Num guesses: 4, Secret: (2, 5, 5, 5)
# Num guesses: 5, Secret: (3, 0, 0, 0)
# Num guesses: 4, Secret: (3, 0, 0, 1)
# Num guesses: 4, Secret: (3, 0, 0, 2)
# Num guesses: 5, Secret: (3, 0, 0, 3)
# Num guesses: 5, Secret: (3, 0, 0, 4)
# Num guesses: 5, Secret: (3, 0, 0, 5)
# Num guesses: 4, Secret: (3, 0, 1, 0)
# Num guesses: 5, Secret: (3, 0, 1, 1)
# Num guesses: 4, Secret: (3, 0, 1, 2)
# Num guesses: 5, Secret: (3, 0, 1, 3)
# Num guesses: 4, Secret: (3, 0, 1, 4)
# Num guesses: 5, Secret: (3, 0, 1, 5)
# Num guesses: 4, Secret: (3, 0, 2, 0)
# Num guesses: 4, Secret: (3, 0, 2, 1)
# Num guesses: 4, Secret: (3, 0, 2, 2)
# Num guesses: 4, Secret: (3, 0, 2, 3)
# Num guesses: 4, Secret: (3, 0, 2, 4)
# Num guesses: 4, Secret: (3, 0, 2, 5)
# Num guesses: 5, Secret: (3, 0, 3, 0)
# Num guesses: 5, Secret: (3, 0, 3, 1)
# Num guesses: 4, Secret: (3, 0, 3, 2)
# Num guesses: 5, Secret: (3, 0, 3, 3)
# Num guesses: 5, Secret: (3, 0, 3, 4)
# Num guesses: 5, Secret: (3, 0, 3, 5)
# Num guesses: 5, Secret: (3, 0, 4, 0)
# Num guesses: 5, Secret: (3, 0, 4, 1)
# Num guesses: 4, Secret: (3, 0, 4, 2)
# Num guesses: 5, Secret: (3, 0, 4, 3)
# Num guesses: 5, Secret: (3, 0, 4, 4)
# Num guesses: 5, Secret: (3, 0, 4, 5)
# Num guesses: 5, Secret: (3, 0, 5, 0)
# Num guesses: 5, Secret: (3, 0, 5, 1)
# Num guesses: 4, Secret: (3, 0, 5, 2)
# Num guesses: 5, Secret: (3, 0, 5, 3)
# Num guesses: 5, Secret: (3, 0, 5, 4)
# Num guesses: 5, Secret: (3, 0, 5, 5)
# Num guesses: 4, Secret: (3, 1, 0, 0)
# Num guesses: 5, Secret: (3, 1, 0, 1)
# Num guesses: 4, Secret: (3, 1, 0, 2)
# Num guesses: 4, Secret: (3, 1, 0, 3)
# Num guesses: 5, Secret: (3, 1, 0, 4)
# Num guesses: 5, Secret: (3, 1, 0, 5)
# Num guesses: 5, Secret: (3, 1, 1, 0)
# Num guesses: 5, Secret: (3, 1, 1, 1)
# Num guesses: 5, Secret: (3, 1, 1, 2)
# Num guesses: 5, Secret: (3, 1, 1, 3)
# Num guesses: 5, Secret: (3, 1, 1, 4)
# Num guesses: 5, Secret: (3, 1, 1, 5)
# Num guesses: 4, Secret: (3, 1, 2, 0)
# Num guesses: 5, Secret: (3, 1, 2, 1)
# Num guesses: 4, Secret: (3, 1, 2, 2)
# Num guesses: 4, Secret: (3, 1, 2, 3)
# Num guesses: 4, Secret: (3, 1, 2, 4)
# Num guesses: 4, Secret: (3, 1, 2, 5)
# Num guesses: 4, Secret: (3, 1, 3, 0)
# Num guesses: 5, Secret: (3, 1, 3, 1)
# Num guesses: 4, Secret: (3, 1, 3, 2)
# Num guesses: 5, Secret: (3, 1, 3, 3)
# Num guesses: 5, Secret: (3, 1, 3, 4)
# Num guesses: 5, Secret: (3, 1, 3, 5)
# Num guesses: 4, Secret: (3, 1, 4, 0)
# Num guesses: 5, Secret: (3, 1, 4, 1)
# Num guesses: 4, Secret: (3, 1, 4, 2)
# Num guesses: 5, Secret: (3, 1, 4, 3)
# Num guesses: 5, Secret: (3, 1, 4, 4)
# Num guesses: 5, Secret: (3, 1, 4, 5)
# Num guesses: 5, Secret: (3, 1, 5, 0)
# Num guesses: 5, Secret: (3, 1, 5, 1)
# Num guesses: 4, Secret: (3, 1, 5, 2)
# Num guesses: 5, Secret: (3, 1, 5, 3)
# Num guesses: 5, Secret: (3, 1, 5, 4)
# Num guesses: 5, Secret: (3, 1, 5, 5)
# Num guesses: 5, Secret: (3, 2, 0, 0)
# Num guesses: 4, Secret: (3, 2, 0, 1)
# Num guesses: 5, Secret: (3, 2, 0, 2)
# Num guesses: 5, Secret: (3, 2, 0, 3)
# Num guesses: 5, Secret: (3, 2, 0, 4)
# Num guesses: 5, Secret: (3, 2, 0, 5)
# Num guesses: 4, Secret: (3, 2, 1, 0)
# Num guesses: 4, Secret: (3, 2, 1, 1)
# Num guesses: 5, Secret: (3, 2, 1, 2)
# Num guesses: 5, Secret: (3, 2, 1, 3)
# Num guesses: 5, Secret: (3, 2, 1, 4)
# Num guesses: 5, Secret: (3, 2, 1, 5)
# Num guesses: 5, Secret: (3, 2, 2, 0)
# Num guesses: 5, Secret: (3, 2, 2, 1)
# Num guesses: 5, Secret: (3, 2, 2, 2)
# Num guesses: 5, Secret: (3, 2, 2, 3)
# Num guesses: 5, Secret: (3, 2, 2, 4)
# Num guesses: 5, Secret: (3, 2, 2, 5)
# Num guesses: 5, Secret: (3, 2, 3, 0)
# Num guesses: 5, Secret: (3, 2, 3, 1)
# Num guesses: 5, Secret: (3, 2, 3, 2)
# Num guesses: 5, Secret: (3, 2, 3, 3)
# Num guesses: 5, Secret: (3, 2, 3, 4)
# Num guesses: 5, Secret: (3, 2, 3, 5)
# Num guesses: 5, Secret: (3, 2, 4, 0)
# Num guesses: 5, Secret: (3, 2, 4, 1)
# Num guesses: 4, Secret: (3, 2, 4, 2)
# Num guesses: 4, Secret: (3, 2, 4, 3)
# Num guesses: 5, Secret: (3, 2, 4, 4)
# Num guesses: 5, Secret: (3, 2, 4, 5)
# Num guesses: 5, Secret: (3, 2, 5, 0)
# Num guesses: 5, Secret: (3, 2, 5, 1)
# Num guesses: 5, Secret: (3, 2, 5, 2)
# Num guesses: 5, Secret: (3, 2, 5, 3)
# Num guesses: 5, Secret: (3, 2, 5, 4)
# Num guesses: 5, Secret: (3, 2, 5, 5)
# Num guesses: 5, Secret: (3, 3, 0, 0)
# Num guesses: 5, Secret: (3, 3, 0, 1)
# Num guesses: 4, Secret: (3, 3, 0, 2)
# Num guesses: 5, Secret: (3, 3, 0, 3)
# Num guesses: 5, Secret: (3, 3, 0, 4)
# Num guesses: 5, Secret: (3, 3, 0, 5)
# Num guesses: 5, Secret: (3, 3, 1, 0)
# Num guesses: 5, Secret: (3, 3, 1, 1)
# Num guesses: 4, Secret: (3, 3, 1, 2)
# Num guesses: 5, Secret: (3, 3, 1, 3)
# Num guesses: 5, Secret: (3, 3, 1, 4)
# Num guesses: 5, Secret: (3, 3, 1, 5)
# Num guesses: 4, Secret: (3, 3, 2, 0)
# Num guesses: 4, Secret: (3, 3, 2, 1)
# Num guesses: 4, Secret: (3, 3, 2, 2)
# Num guesses: 5, Secret: (3, 3, 2, 3)
# Num guesses: 5, Secret: (3, 3, 2, 4)
# Num guesses: 5, Secret: (3, 3, 2, 5)
# Num guesses: 5, Secret: (3, 3, 3, 0)
# Num guesses: 5, Secret: (3, 3, 3, 1)
# Num guesses: 5, Secret: (3, 3, 3, 2)
# Num guesses: 4, Secret: (3, 3, 3, 3)
# Num guesses: 5, Secret: (3, 3, 3, 4)
# Num guesses: 5, Secret: (3, 3, 3, 5)
# Num guesses: 5, Secret: (3, 3, 4, 0)
# Num guesses: 5, Secret: (3, 3, 4, 1)
# Num guesses: 5, Secret: (3, 3, 4, 2)
# Num guesses: 5, Secret: (3, 3, 4, 3)
# Num guesses: 5, Secret: (3, 3, 4, 4)
# Num guesses: 5, Secret: (3, 3, 4, 5)
# Num guesses: 5, Secret: (3, 3, 5, 0)
# Num guesses: 5, Secret: (3, 3, 5, 1)
# Num guesses: 5, Secret: (3, 3, 5, 2)
# Num guesses: 4, Secret: (3, 3, 5, 3)
# Num guesses: 5, Secret: (3, 3, 5, 4)
# Num guesses: 5, Secret: (3, 3, 5, 5)
# Num guesses: 5, Secret: (3, 4, 0, 0)
# Num guesses: 5, Secret: (3, 4, 0, 1)
# Num guesses: 5, Secret: (3, 4, 0, 2)
# Num guesses: 5, Secret: (3, 4, 0, 3)
# Num guesses: 5, Secret: (3, 4, 0, 4)
# Num guesses: 4, Secret: (3, 4, 0, 5)
# Num guesses: 5, Secret: (3, 4, 1, 0)
# Num guesses: 5, Secret: (3, 4, 1, 1)
# Num guesses: 5, Secret: (3, 4, 1, 2)
# Num guesses: 5, Secret: (3, 4, 1, 3)
# Num guesses: 5, Secret: (3, 4, 1, 4)
# Num guesses: 5, Secret: (3, 4, 1, 5)
# Num guesses: 5, Secret: (3, 4, 2, 0)
# Num guesses: 5, Secret: (3, 4, 2, 1)
# Num guesses: 4, Secret: (3, 4, 2, 2)
# Num guesses: 5, Secret: (3, 4, 2, 3)
# Num guesses: 5, Secret: (3, 4, 2, 4)
# Num guesses: 5, Secret: (3, 4, 2, 5)
# Num guesses: 5, Secret: (3, 4, 3, 0)
# Num guesses: 5, Secret: (3, 4, 3, 1)
# Num guesses: 4, Secret: (3, 4, 3, 2)
# Num guesses: 5, Secret: (3, 4, 3, 3)
# Num guesses: 5, Secret: (3, 4, 3, 4)
# Num guesses: 5, Secret: (3, 4, 3, 5)
# Num guesses: 5, Secret: (3, 4, 4, 0)
# Num guesses: 5, Secret: (3, 4, 4, 1)
# Num guesses: 5, Secret: (3, 4, 4, 2)
# Num guesses: 5, Secret: (3, 4, 4, 3)
# Num guesses: 5, Secret: (3, 4, 4, 4)
# Num guesses: 5, Secret: (3, 4, 4, 5)
# Num guesses: 5, Secret: (3, 4, 5, 0)
# Num guesses: 5, Secret: (3, 4, 5, 1)
# Num guesses: 5, Secret: (3, 4, 5, 2)
# Num guesses: 5, Secret: (3, 4, 5, 3)
# Num guesses: 5, Secret: (3, 4, 5, 4)
# Num guesses: 5, Secret: (3, 4, 5, 5)
# Num guesses: 5, Secret: (3, 5, 0, 0)
# Num guesses: 5, Secret: (3, 5, 0, 1)
# Num guesses: 5, Secret: (3, 5, 0, 2)
# Num guesses: 5, Secret: (3, 5, 0, 3)
# Num guesses: 5, Secret: (3, 5, 0, 4)
# Num guesses: 5, Secret: (3, 5, 0, 5)
# Num guesses: 5, Secret: (3, 5, 1, 0)
# Num guesses: 5, Secret: (3, 5, 1, 1)
# Num guesses: 5, Secret: (3, 5, 1, 2)
# Num guesses: 5, Secret: (3, 5, 1, 3)
# Num guesses: 5, Secret: (3, 5, 1, 4)
# Num guesses: 5, Secret: (3, 5, 1, 5)
# Num guesses: 5, Secret: (3, 5, 2, 0)
# Num guesses: 5, Secret: (3, 5, 2, 1)
# Num guesses: 5, Secret: (3, 5, 2, 2)
# Num guesses: 5, Secret: (3, 5, 2, 3)
# Num guesses: 5, Secret: (3, 5, 2, 4)
# Num guesses: 5, Secret: (3, 5, 2, 5)
# Num guesses: 5, Secret: (3, 5, 3, 0)
# Num guesses: 5, Secret: (3, 5, 3, 1)
# Num guesses: 5, Secret: (3, 5, 3, 2)
# Num guesses: 5, Secret: (3, 5, 3, 3)
# Num guesses: 5, Secret: (3, 5, 3, 4)
# Num guesses: 5, Secret: (3, 5, 3, 5)
# Num guesses: 5, Secret: (3, 5, 4, 0)
# Num guesses: 5, Secret: (3, 5, 4, 1)
# Num guesses: 3, Secret: (3, 5, 4, 2)
# Num guesses: 5, Secret: (3, 5, 4, 3)
# Num guesses: 5, Secret: (3, 5, 4, 4)
# Num guesses: 5, Secret: (3, 5, 4, 5)
# Num guesses: 5, Secret: (3, 5, 5, 0)
# Num guesses: 5, Secret: (3, 5, 5, 1)
# Num guesses: 5, Secret: (3, 5, 5, 2)
# Num guesses: 5, Secret: (3, 5, 5, 3)
# Num guesses: 5, Secret: (3, 5, 5, 4)
# Num guesses: 5, Secret: (3, 5, 5, 5)
# Num guesses: 5, Secret: (4, 0, 0, 0)
# Num guesses: 4, Secret: (4, 0, 0, 1)
# Num guesses: 4, Secret: (4, 0, 0, 2)
# Num guesses: 5, Secret: (4, 0, 0, 3)
# Num guesses: 5, Secret: (4, 0, 0, 4)
# Num guesses: 5, Secret: (4, 0, 0, 5)
# Num guesses: 4, Secret: (4, 0, 1, 0)
# Num guesses: 5, Secret: (4, 0, 1, 1)
# Num guesses: 4, Secret: (4, 0, 1, 2)
# Num guesses: 4, Secret: (4, 0, 1, 3)
# Num guesses: 5, Secret: (4, 0, 1, 4)
# Num guesses: 5, Secret: (4, 0, 1, 5)
# Num guesses: 4, Secret: (4, 0, 2, 0)
# Num guesses: 5, Secret: (4, 0, 2, 1)
# Num guesses: 5, Secret: (4, 0, 2, 2)
# Num guesses: 5, Secret: (4, 0, 2, 3)
# Num guesses: 5, Secret: (4, 0, 2, 4)
# Num guesses: 5, Secret: (4, 0, 2, 5)
# Num guesses: 5, Secret: (4, 0, 3, 0)
# Num guesses: 5, Secret: (4, 0, 3, 1)
# Num guesses: 5, Secret: (4, 0, 3, 2)
# Num guesses: 4, Secret: (4, 0, 3, 3)
# Num guesses: 5, Secret: (4, 0, 3, 4)
# Num guesses: 5, Secret: (4, 0, 3, 5)
# Num guesses: 5, Secret: (4, 0, 4, 0)
# Num guesses: 5, Secret: (4, 0, 4, 1)
# Num guesses: 5, Secret: (4, 0, 4, 2)
# Num guesses: 5, Secret: (4, 0, 4, 3)
# Num guesses: 5, Secret: (4, 0, 4, 4)
# Num guesses: 5, Secret: (4, 0, 4, 5)
# Num guesses: 5, Secret: (4, 0, 5, 0)
# Num guesses: 5, Secret: (4, 0, 5, 1)
# Num guesses: 5, Secret: (4, 0, 5, 2)
# Num guesses: 5, Secret: (4, 0, 5, 3)
# Num guesses: 5, Secret: (4, 0, 5, 4)
# Num guesses: 5, Secret: (4, 0, 5, 5)
# Num guesses: 4, Secret: (4, 1, 0, 0)
# Num guesses: 5, Secret: (4, 1, 0, 1)
# Num guesses: 5, Secret: (4, 1, 0, 2)
# Num guesses: 5, Secret: (4, 1, 0, 3)
# Num guesses: 5, Secret: (4, 1, 0, 4)
# Num guesses: 5, Secret: (4, 1, 0, 5)
# Num guesses: 5, Secret: (4, 1, 1, 0)
# Num guesses: 4, Secret: (4, 1, 1, 1)
# Num guesses: 5, Secret: (4, 1, 1, 2)
# Num guesses: 5, Secret: (4, 1, 1, 3)
# Num guesses: 5, Secret: (4, 1, 1, 4)
# Num guesses: 5, Secret: (4, 1, 1, 5)
# Num guesses: 5, Secret: (4, 1, 2, 0)
# Num guesses: 5, Secret: (4, 1, 2, 1)
# Num guesses: 5, Secret: (4, 1, 2, 2)
# Num guesses: 5, Secret: (4, 1, 2, 3)
# Num guesses: 5, Secret: (4, 1, 2, 4)
# Num guesses: 5, Secret: (4, 1, 2, 5)
# Num guesses: 4, Secret: (4, 1, 3, 0)
# Num guesses: 5, Secret: (4, 1, 3, 1)
# Num guesses: 5, Secret: (4, 1, 3, 2)
# Num guesses: 4, Secret: (4, 1, 3, 3)
# Num guesses: 5, Secret: (4, 1, 3, 4)
# Num guesses: 5, Secret: (4, 1, 3, 5)
# Num guesses: 5, Secret: (4, 1, 4, 0)
# Num guesses: 4, Secret: (4, 1, 4, 1)
# Num guesses: 5, Secret: (4, 1, 4, 2)
# Num guesses: 5, Secret: (4, 1, 4, 3)
# Num guesses: 5, Secret: (4, 1, 4, 4)
# Num guesses: 5, Secret: (4, 1, 4, 5)
# Num guesses: 5, Secret: (4, 1, 5, 0)
# Num guesses: 5, Secret: (4, 1, 5, 1)
# Num guesses: 5, Secret: (4, 1, 5, 2)
# Num guesses: 5, Secret: (4, 1, 5, 3)
# Num guesses: 5, Secret: (4, 1, 5, 4)
# Num guesses: 5, Secret: (4, 1, 5, 5)
# Num guesses: 4, Secret: (4, 2, 0, 0)
# Num guesses: 5, Secret: (4, 2, 0, 1)
# Num guesses: 4, Secret: (4, 2, 0, 2)
# Num guesses: 4, Secret: (4, 2, 0, 3)
# Num guesses: 5, Secret: (4, 2, 0, 4)
# Num guesses: 5, Secret: (4, 2, 0, 5)
# Num guesses: 5, Secret: (4, 2, 1, 0)
# Num guesses: 5, Secret: (4, 2, 1, 1)
# Num guesses: 4, Secret: (4, 2, 1, 2)
# Num guesses: 5, Secret: (4, 2, 1, 3)
# Num guesses: 5, Secret: (4, 2, 1, 4)
# Num guesses: 5, Secret: (4, 2, 1, 5)
# Num guesses: 5, Secret: (4, 2, 2, 0)
# Num guesses: 5, Secret: (4, 2, 2, 1)
# Num guesses: 5, Secret: (4, 2, 2, 2)
# Num guesses: 4, Secret: (4, 2, 2, 3)
# Num guesses: 5, Secret: (4, 2, 2, 4)
# Num guesses: 5, Secret: (4, 2, 2, 5)
# Num guesses: 5, Secret: (4, 2, 3, 0)
# Num guesses: 5, Secret: (4, 2, 3, 1)
# Num guesses: 5, Secret: (4, 2, 3, 2)
# Num guesses: 4, Secret: (4, 2, 3, 3)
# Num guesses: 5, Secret: (4, 2, 3, 4)
# Num guesses: 5, Secret: (4, 2, 3, 5)
# Num guesses: 5, Secret: (4, 2, 4, 0)
# Num guesses: 5, Secret: (4, 2, 4, 1)
# Num guesses: 5, Secret: (4, 2, 4, 2)
# Num guesses: 5, Secret: (4, 2, 4, 3)
# Num guesses: 5, Secret: (4, 2, 4, 4)
# Num guesses: 5, Secret: (4, 2, 4, 5)
# Num guesses: 5, Secret: (4, 2, 5, 0)
# Num guesses: 5, Secret: (4, 2, 5, 1)
# Num guesses: 5, Secret: (4, 2, 5, 2)
# Num guesses: 5, Secret: (4, 2, 5, 3)
# Num guesses: 5, Secret: (4, 2, 5, 4)
# Num guesses: 5, Secret: (4, 2, 5, 5)
# Num guesses: 5, Secret: (4, 3, 0, 0)
# Num guesses: 5, Secret: (4, 3, 0, 1)
# Num guesses: 5, Secret: (4, 3, 0, 2)
# Num guesses: 5, Secret: (4, 3, 0, 3)
# Num guesses: 5, Secret: (4, 3, 0, 4)
# Num guesses: 5, Secret: (4, 3, 0, 5)
# Num guesses: 5, Secret: (4, 3, 1, 0)
# Num guesses: 5, Secret: (4, 3, 1, 1)
# Num guesses: 5, Secret: (4, 3, 1, 2)
# Num guesses: 5, Secret: (4, 3, 1, 3)
# Num guesses: 5, Secret: (4, 3, 1, 4)
# Num guesses: 5, Secret: (4, 3, 1, 5)
# Num guesses: 5, Secret: (4, 3, 2, 0)
# Num guesses: 5, Secret: (4, 3, 2, 1)
# Num guesses: 4, Secret: (4, 3, 2, 2)
# Num guesses: 5, Secret: (4, 3, 2, 3)
# Num guesses: 5, Secret: (4, 3, 2, 4)
# Num guesses: 5, Secret: (4, 3, 2, 5)
# Num guesses: 5, Secret: (4, 3, 3, 0)
# Num guesses: 5, Secret: (4, 3, 3, 1)
# Num guesses: 5, Secret: (4, 3, 3, 2)
# Num guesses: 5, Secret: (4, 3, 3, 3)
# Num guesses: 5, Secret: (4, 3, 3, 4)
# Num guesses: 5, Secret: (4, 3, 3, 5)
# Num guesses: 5, Secret: (4, 3, 4, 0)
# Num guesses: 5, Secret: (4, 3, 4, 1)
# Num guesses: 5, Secret: (4, 3, 4, 2)
# Num guesses: 5, Secret: (4, 3, 4, 3)
# Num guesses: 5, Secret: (4, 3, 4, 4)
# Num guesses: 5, Secret: (4, 3, 4, 5)
# Num guesses: 5, Secret: (4, 3, 5, 0)
# Num guesses: 5, Secret: (4, 3, 5, 1)
# Num guesses: 5, Secret: (4, 3, 5, 2)
# Num guesses: 5, Secret: (4, 3, 5, 3)
# Num guesses: 5, Secret: (4, 3, 5, 4)
# Num guesses: 5, Secret: (4, 3, 5, 5)
# Num guesses: 4, Secret: (4, 4, 0, 0)
# Num guesses: 5, Secret: (4, 4, 0, 1)
# Num guesses: 5, Secret: (4, 4, 0, 2)
# Num guesses: 5, Secret: (4, 4, 0, 3)
# Num guesses: 5, Secret: (4, 4, 0, 4)
# Num guesses: 5, Secret: (4, 4, 0, 5)
# Num guesses: 5, Secret: (4, 4, 1, 0)
# Num guesses: 4, Secret: (4, 4, 1, 1)
# Num guesses: 5, Secret: (4, 4, 1, 2)
# Num guesses: 5, Secret: (4, 4, 1, 3)
# Num guesses: 5, Secret: (4, 4, 1, 4)
# Num guesses: 5, Secret: (4, 4, 1, 5)
# Num guesses: 5, Secret: (4, 4, 2, 0)
# Num guesses: 5, Secret: (4, 4, 2, 1)
# Num guesses: 4, Secret: (4, 4, 2, 2)
# Num guesses: 5, Secret: (4, 4, 2, 3)
# Num guesses: 5, Secret: (4, 4, 2, 4)
# Num guesses: 5, Secret: (4, 4, 2, 5)
# Num guesses: 5, Secret: (4, 4, 3, 0)
# Num guesses: 5, Secret: (4, 4, 3, 1)
# Num guesses: 5, Secret: (4, 4, 3, 2)
# Num guesses: 5, Secret: (4, 4, 3, 3)
# Num guesses: 5, Secret: (4, 4, 3, 4)
# Num guesses: 5, Secret: (4, 4, 3, 5)
# Num guesses: 5, Secret: (4, 4, 4, 0)
# Num guesses: 5, Secret: (4, 4, 4, 1)
# Num guesses: 4, Secret: (4, 4, 4, 2)
# Num guesses: 5, Secret: (4, 4, 4, 3)
# Num guesses: 5, Secret: (4, 4, 4, 4)
# Num guesses: 4, Secret: (4, 4, 4, 5)
# Num guesses: 5, Secret: (4, 4, 5, 0)
# Num guesses: 5, Secret: (4, 4, 5, 1)
# Num guesses: 5, Secret: (4, 4, 5, 2)
# Num guesses: 5, Secret: (4, 4, 5, 3)
# Num guesses: 4, Secret: (4, 4, 5, 4)
# Num guesses: 4, Secret: (4, 4, 5, 5)
# Num guesses: 4, Secret: (4, 5, 0, 0)
# Num guesses: 5, Secret: (4, 5, 0, 1)
# Num guesses: 5, Secret: (4, 5, 0, 2)
# Num guesses: 5, Secret: (4, 5, 0, 3)
# Num guesses: 5, Secret: (4, 5, 0, 4)
# Num guesses: 5, Secret: (4, 5, 0, 5)
# Num guesses: 5, Secret: (4, 5, 1, 0)
# Num guesses: 4, Secret: (4, 5, 1, 1)
# Num guesses: 5, Secret: (4, 5, 1, 2)
# Num guesses: 5, Secret: (4, 5, 1, 3)
# Num guesses: 5, Secret: (4, 5, 1, 4)
# Num guesses: 5, Secret: (4, 5, 1, 5)
# Num guesses: 5, Secret: (4, 5, 2, 0)
# Num guesses: 5, Secret: (4, 5, 2, 1)
# Num guesses: 5, Secret: (4, 5, 2, 2)
# Num guesses: 5, Secret: (4, 5, 2, 3)
# Num guesses: 5, Secret: (4, 5, 2, 4)
# Num guesses: 5, Secret: (4, 5, 2, 5)
# Num guesses: 5, Secret: (4, 5, 3, 0)
# Num guesses: 5, Secret: (4, 5, 3, 1)
# Num guesses: 5, Secret: (4, 5, 3, 2)
# Num guesses: 5, Secret: (4, 5, 3, 3)
# Num guesses: 5, Secret: (4, 5, 3, 4)
# Num guesses: 5, Secret: (4, 5, 3, 5)
# Num guesses: 4, Secret: (4, 5, 4, 0)
# Num guesses: 4, Secret: (4, 5, 4, 1)
# Num guesses: 5, Secret: (4, 5, 4, 2)
# Num guesses: 5, Secret: (4, 5, 4, 3)
# Num guesses: 5, Secret: (4, 5, 4, 4)
# Num guesses: 5, Secret: (4, 5, 4, 5)
# Num guesses: 5, Secret: (4, 5, 5, 0)
# Num guesses: 5, Secret: (4, 5, 5, 1)
# Num guesses: 5, Secret: (4, 5, 5, 2)
# Num guesses: 5, Secret: (4, 5, 5, 3)
# Num guesses: 5, Secret: (4, 5, 5, 4)
# Num guesses: 5, Secret: (4, 5, 5, 5)
# Num guesses: 5, Secret: (5, 0, 0, 0)
# Num guesses: 4, Secret: (5, 0, 0, 1)
# Num guesses: 5, Secret: (5, 0, 0, 2)
# Num guesses: 5, Secret: (5, 0, 0, 3)
# Num guesses: 5, Secret: (5, 0, 0, 4)
# Num guesses: 5, Secret: (5, 0, 0, 5)
# Num guesses: 4, Secret: (5, 0, 1, 0)
# Num guesses: 5, Secret: (5, 0, 1, 1)
# Num guesses: 5, Secret: (5, 0, 1, 2)
# Num guesses: 5, Secret: (5, 0, 1, 3)
# Num guesses: 5, Secret: (5, 0, 1, 4)
# Num guesses: 5, Secret: (5, 0, 1, 5)
# Num guesses: 5, Secret: (5, 0, 2, 0)
# Num guesses: 5, Secret: (5, 0, 2, 1)
# Num guesses: 5, Secret: (5, 0, 2, 2)
# Num guesses: 5, Secret: (5, 0, 2, 3)
# Num guesses: 5, Secret: (5, 0, 2, 4)
# Num guesses: 5, Secret: (5, 0, 2, 5)
# Num guesses: 5, Secret: (5, 0, 3, 0)
# Num guesses: 5, Secret: (5, 0, 3, 1)
# Num guesses: 5, Secret: (5, 0, 3, 2)
# Num guesses: 5, Secret: (5, 0, 3, 3)
# Num guesses: 5, Secret: (5, 0, 3, 4)
# Num guesses: 5, Secret: (5, 0, 3, 5)
# Num guesses: 5, Secret: (5, 0, 4, 0)
# Num guesses: 5, Secret: (5, 0, 4, 1)
# Num guesses: 5, Secret: (5, 0, 4, 2)
# Num guesses: 5, Secret: (5, 0, 4, 3)
# Num guesses: 5, Secret: (5, 0, 4, 4)
# Num guesses: 5, Secret: (5, 0, 4, 5)
# Num guesses: 5, Secret: (5, 0, 5, 0)
# Num guesses: 4, Secret: (5, 0, 5, 1)
# Num guesses: 5, Secret: (5, 0, 5, 2)
# Num guesses: 5, Secret: (5, 0, 5, 3)
# Num guesses: 5, Secret: (5, 0, 5, 4)
# Num guesses: 5, Secret: (5, 0, 5, 5)
# Num guesses: 4, Secret: (5, 1, 0, 0)
# Num guesses: 5, Secret: (5, 1, 0, 1)
# Num guesses: 5, Secret: (5, 1, 0, 2)
# Num guesses: 5, Secret: (5, 1, 0, 3)
# Num guesses: 5, Secret: (5, 1, 0, 4)
# Num guesses: 5, Secret: (5, 1, 0, 5)
# Num guesses: 5, Secret: (5, 1, 1, 0)
# Num guesses: 5, Secret: (5, 1, 1, 1)
# Num guesses: 5, Secret: (5, 1, 1, 2)
# Num guesses: 5, Secret: (5, 1, 1, 3)
# Num guesses: 5, Secret: (5, 1, 1, 4)
# Num guesses: 5, Secret: (5, 1, 1, 5)
# Num guesses: 5, Secret: (5, 1, 2, 0)
# Num guesses: 5, Secret: (5, 1, 2, 1)
# Num guesses: 5, Secret: (5, 1, 2, 2)
# Num guesses: 5, Secret: (5, 1, 2, 3)
# Num guesses: 5, Secret: (5, 1, 2, 4)
# Num guesses: 5, Secret: (5, 1, 2, 5)
# Num guesses: 5, Secret: (5, 1, 3, 0)
# Num guesses: 5, Secret: (5, 1, 3, 1)
# Num guesses: 5, Secret: (5, 1, 3, 2)
# Num guesses: 5, Secret: (5, 1, 3, 3)
# Num guesses: 5, Secret: (5, 1, 3, 4)
# Num guesses: 5, Secret: (5, 1, 3, 5)
# Num guesses: 5, Secret: (5, 1, 4, 0)
# Num guesses: 5, Secret: (5, 1, 4, 1)
# Num guesses: 5, Secret: (5, 1, 4, 2)
# Num guesses: 5, Secret: (5, 1, 4, 3)
# Num guesses: 5, Secret: (5, 1, 4, 4)
# Num guesses: 5, Secret: (5, 1, 4, 5)
# Num guesses: 5, Secret: (5, 1, 5, 0)
# Num guesses: 4, Secret: (5, 1, 5, 1)
# Num guesses: 5, Secret: (5, 1, 5, 2)
# Num guesses: 5, Secret: (5, 1, 5, 3)
# Num guesses: 5, Secret: (5, 1, 5, 4)
# Num guesses: 5, Secret: (5, 1, 5, 5)
# Num guesses: 5, Secret: (5, 2, 0, 0)
# Num guesses: 5, Secret: (5, 2, 0, 1)
# Num guesses: 5, Secret: (5, 2, 0, 2)
# Num guesses: 5, Secret: (5, 2, 0, 3)
# Num guesses: 5, Secret: (5, 2, 0, 4)
# Num guesses: 5, Secret: (5, 2, 0, 5)
# Num guesses: 5, Secret: (5, 2, 1, 0)
# Num guesses: 5, Secret: (5, 2, 1, 1)
# Num guesses: 5, Secret: (5, 2, 1, 2)
# Num guesses: 5, Secret: (5, 2, 1, 3)
# Num guesses: 5, Secret: (5, 2, 1, 4)
# Num guesses: 5, Secret: (5, 2, 1, 5)
# Num guesses: 5, Secret: (5, 2, 2, 0)
# Num guesses: 5, Secret: (5, 2, 2, 1)
# Num guesses: 5, Secret: (5, 2, 2, 2)
# Num guesses: 5, Secret: (5, 2, 2, 3)
# Num guesses: 5, Secret: (5, 2, 2, 4)
# Num guesses: 5, Secret: (5, 2, 2, 5)
# Num guesses: 5, Secret: (5, 2, 3, 0)
# Num guesses: 5, Secret: (5, 2, 3, 1)
# Num guesses: 5, Secret: (5, 2, 3, 2)
# Num guesses: 5, Secret: (5, 2, 3, 3)
# Num guesses: 5, Secret: (5, 2, 3, 4)
# Num guesses: 5, Secret: (5, 2, 3, 5)
# Num guesses: 5, Secret: (5, 2, 4, 0)
# Num guesses: 5, Secret: (5, 2, 4, 1)
# Num guesses: 5, Secret: (5, 2, 4, 2)
# Num guesses: 5, Secret: (5, 2, 4, 3)
# Num guesses: 5, Secret: (5, 2, 4, 4)
# Num guesses: 5, Secret: (5, 2, 4, 5)
# Num guesses: 5, Secret: (5, 2, 5, 0)
# Num guesses: 5, Secret: (5, 2, 5, 1)
# Num guesses: 5, Secret: (5, 2, 5, 2)
# Num guesses: 5, Secret: (5, 2, 5, 3)
# Num guesses: 4, Secret: (5, 2, 5, 4)
# Num guesses: 5, Secret: (5, 2, 5, 5)
# Num guesses: 5, Secret: (5, 3, 0, 0)
# Num guesses: 5, Secret: (5, 3, 0, 1)
# Num guesses: 5, Secret: (5, 3, 0, 2)
# Num guesses: 5, Secret: (5, 3, 0, 3)
# Num guesses: 5, Secret: (5, 3, 0, 4)
# Num guesses: 5, Secret: (5, 3, 0, 5)
# Num guesses: 5, Secret: (5, 3, 1, 0)
# Num guesses: 5, Secret: (5, 3, 1, 1)
# Num guesses: 5, Secret: (5, 3, 1, 2)
# Num guesses: 5, Secret: (5, 3, 1, 3)
# Num guesses: 5, Secret: (5, 3, 1, 4)
# Num guesses: 5, Secret: (5, 3, 1, 5)
# Num guesses: 5, Secret: (5, 3, 2, 0)
# Num guesses: 5, Secret: (5, 3, 2, 1)
# Num guesses: 5, Secret: (5, 3, 2, 2)
# Num guesses: 5, Secret: (5, 3, 2, 3)
# Num guesses: 5, Secret: (5, 3, 2, 4)
# Num guesses: 5, Secret: (5, 3, 2, 5)
# Num guesses: 5, Secret: (5, 3, 3, 0)
# Num guesses: 5, Secret: (5, 3, 3, 1)
# Num guesses: 5, Secret: (5, 3, 3, 2)
# Num guesses: 4, Secret: (5, 3, 3, 3)
# Num guesses: 5, Secret: (5, 3, 3, 4)
# Num guesses: 5, Secret: (5, 3, 3, 5)
# Num guesses: 5, Secret: (5, 3, 4, 0)
# Num guesses: 5, Secret: (5, 3, 4, 1)
# Num guesses: 5, Secret: (5, 3, 4, 2)
# Num guesses: 5, Secret: (5, 3, 4, 3)
# Num guesses: 5, Secret: (5, 3, 4, 4)
# Num guesses: 5, Secret: (5, 3, 4, 5)
# Num guesses: 5, Secret: (5, 3, 5, 0)
# Num guesses: 5, Secret: (5, 3, 5, 1)
# Num guesses: 5, Secret: (5, 3, 5, 2)
# Num guesses: 5, Secret: (5, 3, 5, 3)
# Num guesses: 5, Secret: (5, 3, 5, 4)
# Num guesses: 5, Secret: (5, 3, 5, 5)
# Num guesses: 4, Secret: (5, 4, 0, 0)
# Num guesses: 5, Secret: (5, 4, 0, 1)
# Num guesses: 5, Secret: (5, 4, 0, 2)
# Num guesses: 5, Secret: (5, 4, 0, 3)
# Num guesses: 5, Secret: (5, 4, 0, 4)
# Num guesses: 5, Secret: (5, 4, 0, 5)
# Num guesses: 5, Secret: (5, 4, 1, 0)
# Num guesses: 4, Secret: (5, 4, 1, 1)
# Num guesses: 5, Secret: (5, 4, 1, 2)
# Num guesses: 5, Secret: (5, 4, 1, 3)
# Num guesses: 5, Secret: (5, 4, 1, 4)
# Num guesses: 5, Secret: (5, 4, 1, 5)
# Num guesses: 5, Secret: (5, 4, 2, 0)
# Num guesses: 5, Secret: (5, 4, 2, 1)
# Num guesses: 5, Secret: (5, 4, 2, 2)
# Num guesses: 5, Secret: (5, 4, 2, 3)
# Num guesses: 5, Secret: (5, 4, 2, 4)
# Num guesses: 5, Secret: (5, 4, 2, 5)
# Num guesses: 5, Secret: (5, 4, 3, 0)
# Num guesses: 5, Secret: (5, 4, 3, 1)
# Num guesses: 5, Secret: (5, 4, 3, 2)
# Num guesses: 5, Secret: (5, 4, 3, 3)
# Num guesses: 5, Secret: (5, 4, 3, 4)
# Num guesses: 5, Secret: (5, 4, 3, 5)
# Num guesses: 5, Secret: (5, 4, 4, 0)
# Num guesses: 5, Secret: (5, 4, 4, 1)
# Num guesses: 5, Secret: (5, 4, 4, 2)
# Num guesses: 5, Secret: (5, 4, 4, 3)
# Num guesses: 5, Secret: (5, 4, 4, 4)
# Num guesses: 5, Secret: (5, 4, 4, 5)
# Num guesses: 5, Secret: (5, 4, 5, 0)
# Num guesses: 5, Secret: (5, 4, 5, 1)
# Num guesses: 5, Secret: (5, 4, 5, 2)
# Num guesses: 5, Secret: (5, 4, 5, 3)
# Num guesses: 4, Secret: (5, 4, 5, 4)
# Num guesses: 5, Secret: (5, 4, 5, 5)
# Num guesses: 4, Secret: (5, 5, 0, 0)
# Num guesses: 5, Secret: (5, 5, 0, 1)
# Num guesses: 5, Secret: (5, 5, 0, 2)
# Num guesses: 5, Secret: (5, 5, 0, 3)
# Num guesses: 5, Secret: (5, 5, 0, 4)
# Num guesses: 4, Secret: (5, 5, 0, 5)
# Num guesses: 5, Secret: (5, 5, 1, 0)
# Num guesses: 4, Secret: (5, 5, 1, 1)
# Num guesses: 5, Secret: (5, 5, 1, 2)
# Num guesses: 5, Secret: (5, 5, 1, 3)
# Num guesses: 5, Secret: (5, 5, 1, 4)
# Num guesses: 4, Secret: (5, 5, 1, 5)
# Num guesses: 5, Secret: (5, 5, 2, 0)
# Num guesses: 5, Secret: (5, 5, 2, 1)
# Num guesses: 5, Secret: (5, 5, 2, 2)
# Num guesses: 3, Secret: (5, 5, 2, 3)
# Num guesses: 5, Secret: (5, 5, 2, 4)
# Num guesses: 5, Secret: (5, 5, 2, 5)
# Num guesses: 5, Secret: (5, 5, 3, 0)
# Num guesses: 5, Secret: (5, 5, 3, 1)
# Num guesses: 5, Secret: (5, 5, 3, 2)
# Num guesses: 5, Secret: (5, 5, 3, 3)
# Num guesses: 5, Secret: (5, 5, 3, 4)
# Num guesses: 5, Secret: (5, 5, 3, 5)
# Num guesses: 5, Secret: (5, 5, 4, 0)
# Num guesses: 5, Secret: (5, 5, 4, 1)
# Num guesses: 5, Secret: (5, 5, 4, 2)
# Num guesses: 5, Secret: (5, 5, 4, 3)
# Num guesses: 4, Secret: (5, 5, 4, 4)
# Num guesses: 5, Secret: (5, 5, 4, 5)
# Num guesses: 4, Secret: (5, 5, 5, 0)
# Num guesses: 4, Secret: (5, 5, 5, 1)
# Num guesses: 5, Secret: (5, 5, 5, 2)
# Num guesses: 5, Secret: (5, 5, 5, 3)
# Num guesses: 5, Secret: (5, 5, 5, 4)
# Num guesses: 3, Secret: (5, 5, 5, 5)
# Counter({1: 1, 2: 6, 3: 25, 4: 239, 5: 1025})
